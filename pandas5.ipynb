# %%
import matplotlib.pyplot as plt

x = [1, 2, 3]
y = [8, 2, 4]

fig, ax = plt.subplots()
ax.barh(x, y)
plt.show()

# %%
fig, ax = plt.subplots()

x = [1, 2, 3]
y1 = [4, 12, 5]
y2 = [8, 2, 4]

ax.bar(x, y1, label='y1')
ax.bar(x, y2, label='y2')
ax.legend()
plt.show()
